# %% [markdown]
# ## Loops and Function

# %%
# Basic for loop
res = []
temp = [1,2,3,4]
for i in temp:
    res.append(i*i)
res
# Out:
# [1, 4, 9, 16]

# %%
# List comprehension way

[x*x for x in temp]
# Out:
# [1, 4, 9, 16]

# %%
import pandas as pd
store_sales = pd.read_csv(r"data\store_sales.csv")
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# 1    21   19
# 2    24    8
# ...

# %%
store_sales.head()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec
# 0    7    6
# 1   21   19
# 2   24    8
# 3    7   11
# 4    6   13

# %%
# find out avg sales for each month
# find out avg sales for each store
store_sales["Jan"].mean()
# Out:
# 14.46

# %% [markdown]
# # Apply function

# %%
store_sales.apply("mean")
# Out:
# C:\Users\vsriniva\AppData\Local\Temp\ipykernel_17860\1462922240.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   store_sales.apply("mean")
# Jan     14.46
# Feb     15.09
# Mar     14.56
# Apr     14.57
# May     13.56
# Jun     13.80
# July    14.38
# Aug     15.81
# Sep     14.91
# Oct     14.10
# Nov     15.31
# Dec     13.57
# dtype: float64

# %%
# Mean for horizontally
store_sales.apply("mean", axis = 1)
# axis = 1 means rows
# By default axis will be 0, it means columns
# Out:
# C:\Users\vsriniva\AppData\Local\Temp\ipykernel_17860\1134329475.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   store_sales.apply("mean", axis = 1)
# 0     14.833333
# 1     14.500000
# 2     15.083333
# 3     11.250000
# 4     13.250000
#         ...
# 95    15.416667
# 96    12.833333
# 97    14.000000
# 98    14.416667
# 99    15.000000
# Length: 100, dtype: float64

# %%
store_sales.apply(["mean","max"])
# Out:
# C:\Users\vsriniva\AppData\Local\Temp\ipykernel_17860\2369136435.py:1: FutureWarning: ['store_id', 'city'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   store_sales.apply(["mean","max"])
#      store_id   city    Jan    Feb    Mar    Apr    May   Jun   July    Aug  \
# mean      NaN    NaN  14.46  15.09  14.56  14.57  13.56  13.8  14.38  15.81
# max      S_99  Texas  24.00  24.00  24.00  24.00  24.00  24.0  24.00  24.00
#
#         Sep   Oct    Nov    Dec
# mean  14.91  14.1  15.31  13.57
# max   24.00  24.0  24.00  24.00

# %%
store_sales.select_dtypes(include = ['int64', 'float64']).apply(["mean","max"])
# Out:
#         Jan    Feb    Mar    Apr    May   Jun   July    Aug    Sep   Oct  \
# mean  14.46  15.09  14.56  14.57  13.56  13.8  14.38  15.81  14.91  14.1
# max   24.00  24.00  24.00  24.00  24.00  24.0  24.00  24.00  24.00  24.0
#
#         Nov    Dec
# mean  15.31  13.57
# max   24.00  24.00

# %%
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec
# 0     7    6
# 1    21   19
# 2    24    8
# ...

# %%
store_sales.groupby("city").apply("mean")
# Out:
#                   Jan        Feb        Mar        Apr        May        Jun  \
# city
# Arizona     15.500000  15.272727  14.545455  14.954545  14.090909  15.090909
# California  14.744186  15.534884  14.627907  13.976744  13.255814  13.697674
# Texas       13.457143  14.428571  14.485714  15.057143  13.600000  13.114286
#
#                  July        Aug        Sep        Oct        Nov        Dec
# city
# Arizona     14.636364  15.500000  15.318182  14.954545  16.409091  13.318182
# California  14.813953  16.232558  14.883721  14.279070  15.279070  13.604651
# Texas       13.685714  15.485714  14.685714  13.342857  14.657143  13.685714

# %%
def bonus_func(sales_numbers):
    return ["Eligible" if x > 15 else "Not Eligible" for x in sales_numbers]

# %%
import numpy as np
def bonus_func(sales_col):
    elig_values = np.where(sales_col >10, "eligible","not_eligible")
    return elig_values
store_sales['Jan_bonus']=bonus_func(store_sales["Jan"])

# %%
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# ..      ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...
# 95     S_96       Texas    7   10   20   20   10   15    15   21   15    7
# 96     S_97  California   13    6    7   15   22   10    21   23   10    6
# 97     S_98       Texas   16    9    6   14   20   13    11   10    8   22
# 98     S_99     Arizona   18   16    9    5   12   22    11   13   21   17
# 99    S_100  California    5   23   17   24   15   21    19   10   12   20
#
#     Nov  Dec     Jan_bonus
# 0     7    6  not_eligible
# ...

# %%
import numpy as np
def bonus_func(sales_col):
    elig_values = np.where(sales_col >10, "eligible","not_eligible")
    return elig_values
#store_sales['Jan_bonus']=bonus_func(store_sales["Jan"])
newdf = store_sales.select_dtypes(include=['int64','float64']).apply(bonus_func)
newdf
# Out:
#              Jan           Feb           Mar           Apr           May  \
# 0   not_eligible      eligible      eligible      eligible      eligible
# 1       eligible      eligible      eligible      eligible      eligible
# 2       eligible      eligible      eligible      eligible      eligible
# 3   not_eligible      eligible      eligible  not_eligible      eligible
# 4       eligible  not_eligible      eligible  not_eligible  not_eligible
# ..           ...           ...           ...           ...           ...
# 95  not_eligible  not_eligible      eligible      eligible  not_eligible
# 96      eligible  not_eligible  not_eligible      eligible      eligible
# 97      eligible  not_eligible  not_eligible      eligible      eligible
# 98      eligible      eligible  not_eligible  not_eligible      eligible
# 99  not_eligible      eligible      eligible      eligible      eligible
#
#              Jun          July           Aug           Sep           Oct  \
# ...

# %%
newdf_combine = pd.concat([store_sales, newdf])
newdf_combine
# Out:
#    store_id        city           Jan           Feb           Mar  \
# 0       S_1       Texas             8            20            13
# 1       S_2  California            12            19            15
# 2       S_3  California            16            16            14
# 3       S_4       Texas             8            18            13
# 4       S_5       Texas            19             5            24
# ..      ...         ...           ...           ...           ...
# 95      NaN         NaN  not_eligible  not_eligible      eligible
# 96      NaN         NaN      eligible  not_eligible  not_eligible
# 97      NaN         NaN      eligible  not_eligible  not_eligible
# 98      NaN         NaN      eligible      eligible  not_eligible
# 99      NaN         NaN  not_eligible      eligible      eligible
#
#              Apr           May           Jun      July           Aug  \
# 0             21            17            20        24            17
# ...

# %%
newdf_combine.shape
# Out:
# (200, 15)

# %%
new= pd.concat([store_sales, newdf], axis = 1)
new
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun July Aug  ...  \
# 0       S_1       Texas    8   20   13   21   17   20   24  17  ...
# 1       S_2  California   12   19   15   15   11   19    7  15  ...
# 2       S_3  California   16   16   14   19   23    6   13  13  ...
# 3       S_4       Texas    8   18   13   10   14   14    6   8  ...
# 4       S_5       Texas   19    5   24    9    5   24   10   5  ...
# ..      ...         ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# 95     S_96       Texas    7   10   20   20   10   15   15  21  ...
# 96     S_97  California   13    6    7   15   22   10   21  23  ...
# 97     S_98       Texas   16    9    6   14   20   13   11  10  ...
# 98     S_99     Arizona   18   16    9    5   12   22   11  13  ...
# 99    S_100  California    5   23   17   24   15   21   19  10  ...
#
#              Mar           Apr           May           Jun          July  \
# 0       eligible      eligible      eligible      eligible      eligible
# ...

# %%
new.shape
# Out:
# (100, 27)

# %%
new.tail()
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun July Aug  ...  \
# 95     S_96       Texas    7   10   20   20   10   15   15  21  ...
# 96     S_97  California   13    6    7   15   22   10   21  23  ...
# 97     S_98       Texas   16    9    6   14   20   13   11  10  ...
# 98     S_99     Arizona   18   16    9    5   12   22   11  13  ...
# 99    S_100  California    5   23   17   24   15   21   19  10  ...
#
#              Mar           Apr           May           Jun      July  \
# 95      eligible      eligible  not_eligible      eligible  eligible
# 96  not_eligible      eligible      eligible  not_eligible  eligible
# 97  not_eligible      eligible      eligible      eligible  eligible
# 98  not_eligible  not_eligible      eligible      eligible  eligible
# 99      eligible      eligible      eligible      eligible  eligible
#
#              Aug           Sep           Oct           Nov           Dec
# ...

# %%
new["Jan"]
# Out:
#    Jan           Jan
# 0    8  not_eligible
# 1   12      eligible
# 2   16      eligible
# 3    8  not_eligible
# 4   19      eligible
# ..  ..           ...
# 95   7  not_eligible
# 96  13      eligible
# 97  16      eligible
# 98  18      eligible
# 99   5  not_eligible
#
# [100 rows x 2 columns]

# %%
new.columns
# Out:
# Index(['store_id', 'city', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'July',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan_bonus', 'Jan', 'Feb', 'Mar',
#        'Apr', 'May', 'Jun', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
new.dropna()
# This will drop rowise
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun July Aug  ...  \
# 0       S_1       Texas    8   20   13   21   17   20   24  17  ...
# 1       S_2  California   12   19   15   15   11   19    7  15  ...
# 2       S_3  California   16   16   14   19   23    6   13  13  ...
# 3       S_4       Texas    8   18   13   10   14   14    6   8  ...
# 4       S_5       Texas   19    5   24    9    5   24   10   5  ...
# ..      ...         ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# 95     S_96       Texas    7   10   20   20   10   15   15  21  ...
# 96     S_97  California   13    6    7   15   22   10   21  23  ...
# 97     S_98       Texas   16    9    6   14   20   13   11  10  ...
# 98     S_99     Arizona   18   16    9    5   12   22   11  13  ...
# 99    S_100  California    5   23   17   24   15   21   19  10  ...
#
#              Mar           Apr           May           Jun          July  \
# 0       eligible      eligible      eligible      eligible      eligible
# ...

# %%
new.dropna(axis=1, thresh=2)
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun July Aug  ...  \
# 0       S_1       Texas    8   20   13   21   17   20   24  17  ...
# 1       S_2  California   12   19   15   15   11   19    7  15  ...
# 2       S_3  California   16   16   14   19   23    6   13  13  ...
# 3       S_4       Texas    8   18   13   10   14   14    6   8  ...
# 4       S_5       Texas   19    5   24    9    5   24   10   5  ...
# ..      ...         ...  ...  ...  ...  ...  ...  ...  ...  ..  ...
# 95     S_96       Texas    7   10   20   20   10   15   15  21  ...
# 96     S_97  California   13    6    7   15   22   10   21  23  ...
# 97     S_98       Texas   16    9    6   14   20   13   11  10  ...
# 98     S_99     Arizona   18   16    9    5   12   22   11  13  ...
# 99    S_100  California    5   23   17   24   15   21   19  10  ...
#
#              Mar           Apr           May           Jun          July  \
# 0       eligible      eligible      eligible      eligible      eligible
# ...
